# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def correlacion_pearson(data_frame, columna1, columna2):
    return np.corrcoef(data_frame[columna1], data_frame[columna2])[0,1];

# %% [markdown]
# ## Resultados Optimos

# %%
optimos = pd.read_csv("resultados/best_results.csv");

# %% [markdown]
# # DataSet Heuristicas 1 y 2

# %% [markdown]
# Leemos el dataset de los resultados

# %%
h1 = pd.read_csv("resultados/Experimento1/h1.csv");
print(h1)
# Out:
#      N  Impacto    Tiempo
# 0    6        1  0.018753
# 1    8        6  0.027046
# 2   10        3  0.029103
# 3   12       12  0.046277
# 4   14       11  0.086619
# 5   16       13  0.073928
# 6   18       17  0.098959
# 7   20       17  0.083345
# 8   22       15  0.154668
# 9   24       21  0.120478
# 10  26       28  0.172261
# 11  28       36  0.175414
# 12  30       36  0.254747

# %%
h2 = pd.read_csv("resultados/Experimento1/h2.csv");
print(h2)
# Out:
#      N  Impacto    Tiempo
# 0    6        1  0.029308
# 1    8        6  0.029398
# 2   10        3  0.047287
# 3   12       16  0.056367
# 4   14       12  0.078044
# 5   16       16  0.098948
# 6   18       20  0.134173
# 7   20       17  0.156297
# 8   22       24  0.218510
# 9   24       23  0.191398
# 10  26       35  0.223358
# 11  28       40  0.269697
# 12  30       40  0.363484

# %% [markdown]
# ## Impacto

# %%
fig = sns.scatterplot(data=h1, x='N', y='Impacto', color="b", label="H1");
fig = sns.scatterplot(data=h2, x='N', y='Impacto', color="c", label="H2");

fig.set_title('Impacto de las heuristicas')
fig.set(xlabel='#Nodos', ylabel='Impacto');
plt.savefig("graficos/h1vsh2IMPACTO.svg");

# %% [markdown]
# ## Tiempo

# %%
fig = sns.scatterplot(data=h1, x='N', y='Tiempo', color="b", label="H1");
fig = sns.scatterplot(data=h2, x='N', y='Tiempo', color="c", label="H2");

fig.set_title('Impacto de las heuristicas')
fig.set(xlabel='#Nodos', ylabel='Tiempo en milisegundos');
plt.savefig("graficos/h1vsh2TIEMPO.svg");

# %% [markdown]
# ## Data set Experimento 3

# %% [markdown]
# # M2

# %%
M2H2 = pd.read_csv("resultados/Experimento3/M2H2.csv");
M2H1 = pd.read_csv("resultados/Experimento3/M2H1.csv");
M1H2 = pd.read_csv("resultados/Experimento3/M1H2.csv");
M1H1 = pd.read_csv("resultados/Experimento3/M1H1.csv");
print(M2H2)
# Out:
#      N  Impacto       Tiempo
# 0    6      1.0     5.073744
# 1    8      6.0     8.104919
# 2   10      3.0  1129.673500
# 3   12     16.0    15.680260
# 4   14     12.0    27.287320
# 5   16     16.0  2477.817000
# 6   18     20.0    49.450375
# 7   20     19.0    74.174495
# 8   22     25.0    99.673170
# 9   24     24.0   115.515250
# 10  26     35.0   136.030000
# 11  28     43.0   156.965000
# 12  30     41.0   214.655500

# %% [markdown]
# Experimentacion para factibilidad:

# %%
print(M2H1)
# Out:
#      N  Impacto      Tiempo
# 0    6      1.0    8.092383
# 1    8      6.0    7.002652
# 2   10      3.0   29.510490
# 3   12     12.0   21.944645
# 4   14     11.0   37.437805
# 5   16     15.0   46.606470
# 6   18     17.0   59.750490
# 7   20     18.0   80.692105
# 8   22     16.0  140.699900
# 9   24     22.0  158.429050
# 10  26     30.0  153.328900
# 11  28     36.0  207.322800
# 12  30     36.0  242.931150

# %%
fig = sns.scatterplot(data=M2H2, x='N', y='Impacto', color="b", label="M2H2");
fig = sns.scatterplot(data=M2H1, x='N', y='Impacto', color="c", label="M2H1");
#fig = sns.scatterplot(data=optimos, x='N', y='Impacto', color="g", label="Impacto optimo");

fig.set_title('Impacto segun la metaheuristica')
fig.set(xlabel='#Nodos', ylabel='Impacto');
plt.savefig("graficos/M21vsM22IMPACTO.png");

# %%
print(M2H2)
# Out:
#      N  Impacto  Tiempo
# 0    6        1     1.0
# 1    8        6     6.0
# 2   10        3     3.0
# 3   12       16    16.0
# 4   14       12    12.0
# 5   16       16    16.0
# 6   18       20    20.0
# 7   20       19    19.0
# 8   22       25    25.0
# 9   24       24    24.0
# 10  26       35    35.0
# 11  28       43    43.0
# 12  30       41    41.0

# %%
fig = sns.scatterplot(data=M2H2, x='N', y='Tiempo', color="b", label="M2H2");
fig = sns.scatterplot(data=M2H1, x='N', y='Tiempo', color="c", label="M2H1");

fig.set_title('Tiempo de ejecucion de metaheuristicas')
fig.set(xlabel='#Nodos', ylabel='Tiempo en milisegundos');
plt.savefig("graficos/M21vsM22TIEMPO.png");

# %% [markdown]
# # M1

# %%
fig = sns.scatterplot(data=M1H2, x='N', y='Impacto', color="r", label="M1H2");
fig = sns.scatterplot(data=M1H1, x='N', y='Impacto', color="g", label="M1H1");
#fig = sns.scatterplot(data=optimos, x='N', y='Impacto', color="g", label="Impacto optimo");

fig.set_title('Impacto segun la metaheuristica')
fig.set(xlabel='#Nodos', ylabel='Impacto');
plt.savefig("graficos/M11vsM12IMPACTO.png");

# %% [markdown]
# # Experimento 3

# %% [markdown]
# ## Data set M2H1

# %%
M2H1 = pd.read_csv("resultados/Experimento3/M2H1.csv");
print(M2H1)
# Out:
#      N  Impacto  Tiempo
# 0    6        1     1.0
# 1    8        6     6.0
# 2   10        3     3.0
# 3   12       12    12.0
# 4   14       11    11.0
# 5   16       15    15.0
# 6   18       17    17.0
# 7   20       18    18.0
# 8   22       16    16.0
# 9   24       22    22.0
# 10  26       30    30.0
# 11  28       36    36.0
# 12  30       36    36.0

# %%
fig = sns.scatterplot(data=M1H2, x='N', y='Tiempo', color="r", label="M1H2");
fig = sns.scatterplot(data=M1H1, x='N', y='Tiempo', color="g", label="M1H1");

fig.set_title('Tiempo de ejecucion de metaheuristicas')
fig.set(xlabel='#Nodos', ylabel='Tiempo en milisegundos');
plt.savefig("graficos/M11vsM12TIEMPO.png");

# %% [markdown]
# # Experimentacion con Variables M2 (DESARROLLO DE METAHEURISTICAS)

# %% [markdown]
# ## Variables Fijas de M2
# * Porcentaje de nodos
# * Max cant de iteraciones
# * Ciclos Max_sin_mejoras

# %% [markdown]
# Considero que el valor estandar de las variables fijas es :
# * Porcentaje de Nodos = 0.8
# * Max cant de iteraciones = 5000
# * Ciclos Max Sin Mejoras = 1000
#
# Cuando se realizen modificaciones a una variable fija,se puede asumir que el resto se encuentra en su valor estandar,a menos que se aclare lo contrario.

# %% [markdown]
# ### Porcentaje de Nodos

# %%
M2H1_estandarALL = pd.read_csv("resultados/Experimento3/M2H1-estandarAll.csv");
M2H1_lowestALL = pd.read_csv("resultados/Experimento3/M2H1-lowestALL.csv");
M2H1_highestALL = pd.read_csv("resultados/Experimento3/M2H1-highestALL.csv");
M2H1_max_iter_1000 = pd.read_csv("resultados/Experimento3/M2H1-max-iter-1000.csv");
M2H1_max_iter_100000 = pd.read_csv("resultados/Experimento3/M2H1-max-iter-100000.csv");
M2H1_max_iter_50000 = pd.read_csv("resultados/Experimento3/M2H1-max-iter-50000.csv");
M2H1_sin_mejoras_2000 = pd.read_csv("resultados/Experimento3/M2H1-sin-mejoras-2000.csv");
M2H1_sin_mejoras_500 = pd.read_csv("resultados/Experimento3/M2H1-sin-mejoras-500.csv");
M2H1_sin_mejoras_5000 = pd.read_csv("resultados/Experimento3/M2H1-sin-mejoras-5000.csv");
M2H1_porcentaje_02 = pd.read_csv("resultados/Experimento3/M2H1-Porcentaje-0.2.csv");
M2H1_porcentaje_04 = pd.read_csv("resultados/Experimento3/M2H1-Porcentaje-0.4.csv");
M2H1_porcentaje_06 = pd.read_csv("resultados/Experimento3/M2H1-Porcentaje-0.6.csv");
M2H1_porcentaje_10 = pd.read_csv("resultados/Experimento3/M2H1-Porcentaje-1.0.csv");

# %%
M2H2_estandarALL = pd.read_csv("resultados/Experimento3/M2H2-estandarAll.csv");
M2H2_lowestALL = pd.read_csv("resultados/Experimento3/M2H2-lowestALL.csv");
M2H2_highestALL = pd.read_csv("resultados/Experimento3/M2H2-highestALL.csv");
M2H2_max_iter_1000 = pd.read_csv("resultados/Experimento3/M2H2-max-iter-1000.csv");
M2H2_max_iter_100000 = pd.read_csv("resultados/Experimento3/M2H2-max-iter-100000.csv");
M2H2_max_iter_50000 = pd.read_csv("resultados/Experimento3/M2H2-max-iter-50000.csv");
M2H2_sin_mejoras_2000 = pd.read_csv("resultados/Experimento3/M2H2-sin-mejoras-2000.csv");
M2H2_sin_mejoras_500 = pd.read_csv("resultados/Experimento3/M2H2-sin-mejoras-500.csv");
M2H2_sin_mejoras_5000 = pd.read_csv("resultados/Experimento3/M2H2-sin-mejoras-5000.csv");
M2H2_porcentaje_02 = pd.read_csv("resultados/Experimento3/M2H2-Porcentaje-0.2.csv");
M2H2_porcentaje_04 = pd.read_csv("resultados/Experimento3/M2H2-Porcentaje-0.4.csv");
M2H2_porcentaje_06 = pd.read_csv("resultados/Experimento3/M2H2-Porcentaje-0.6.csv");
M2H2_porcentaje_10 = pd.read_csv("resultados/Experimento3/M2H2-Porcentaje-1.0.csv");

# %%
print(M2H2_lowestALL)
print(M2H2_estandarALL)
print(M2H2_highestALL)
# Out:
#      N  Impacto      Tiempo
# 0    6      1.0    0.968519
# 1    8      6.0    1.451921
# 2   10      3.0  117.215050
# 3   12     16.0    3.028268
# 4   14     12.0    5.163862
# 5   16     16.0  251.375500
# 6   18     20.0    6.022611
# 7   20     19.0    8.126147
# 8   22     25.0   11.462365
# 9   24     24.0   11.542610
# 10  26     35.0   26.923725
# 11  28     43.0   30.943745
# 12  30     41.0   40.867825
#      N  Impacto       Tiempo
# 0    6      1.0     2.633874
# 1    8      6.0     4.332796
# 2   10      3.0   876.721550
# 3   12     16.0     9.842720
# 4   14     12.0    18.801855
# 5   16     16.0  1966.131500
# 6   18     20.0    35.835165
# 7   20     19.0    55.426155
# 8   22     25.0    77.663100
# 9   24     24.0    88.053230
# 10  26     35.0   101.726730
# 11  28     43.0   120.175200
# 12  30     41.0   161.512850
#      N  Impacto        Tiempo
# 0    6      1.0     16.890880
# 1    8      6.0     26.845460
# 2   10      3.0   5482.073000
# ...

# %% [markdown]
# ## Comparaciones de tiempos

# %%
fig = sns.scatterplot(data=M2H2_lowestALL, x='N', y='Tiempo', color="r", label="M2H2_lowestALL");
fig = sns.scatterplot(data=M2H2_estandarALL, x='N', y='Tiempo', color="g", label="M2H2_estandarALL");
fig = sns.scatterplot(data=M2H2_highestALL, x='N', y='Tiempo', color="b", label="M2H2_highestALL");

fig.set_title('Tiempos de ejecucion de M2H2 (lowest vs estandar vs highest)')
fig.set(xlabel='#Nodos', ylabel='Tiempo en milisegundos');
plt.savefig("graficos/M2H2-stdVSlowVShighTime.png");

# %%
fig = sns.scatterplot(data=M2H1_lowestALL, x='N', y='Tiempo', color="r", label="M2H1_lowestALL");
fig = sns.scatterplot(data=M2H1_estandarALL, x='N', y='Tiempo', color="g", label="M2H1_estandarALL");
fig = sns.scatterplot(data=M2H1_highestALL, x='N', y='Tiempo', color="b", label="M2H1_highestALL");

fig.set_title('Tiempos de ejecucion de M2H1 (lowest vs estandar vs highest)')
fig.set(xlabel='#Nodos', ylabel='Tiempo en milisegundos');
plt.savefig("graficos/M2H1-stdVSlowVShighTime.png");

# %%
fig = sns.scatterplot(data=M2H2_porcentaje_02, x='N', y='Tiempo', color="r", label="M2H2-Porcentaje-0.2");
fig = sns.scatterplot(data=M2H2_porcentaje_04, x='N', y='Tiempo', color="g", label="M2H2-Porcentaje-0.4");
fig = sns.scatterplot(data=M2H2_porcentaje_06, x='N', y='Tiempo', color="b", label="M2H2-Porcentaje-0.6");
fig = sns.scatterplot(data=M2H2_estandarALL, x='N', y='Tiempo', color="yellow", label="M2H2-Porcentaje-0.8");
fig = sns.scatterplot(data=M2H2_porcentaje_10, x='N', y='Tiempo', color="purple", label="M2H2-Porcentaje-1.0");

fig.set_title('Tiempos de ejecucion de M2H2 para distintos porcentajes de nodos')
fig.set(xlabel='#Nodos', ylabel='Tiempo en milisegundos');
plt.savefig("graficos/M2H2-porcentajesTime.png");

# %%
fig = sns.scatterplot(data=M2H1_porcentaje_02, x='N', y='Tiempo', color="r", label="M2H1-Porcentaje-0.2");
fig = sns.scatterplot(data=M2H1_porcentaje_04, x='N', y='Tiempo', color="g", label="M2H1-Porcentaje-0.4");
fig = sns.scatterplot(data=M2H1_porcentaje_06, x='N', y='Tiempo', color="b", label="M2H1-Porcentaje-0.6");
fig = sns.scatterplot(data=M2H1_estandarALL, x='N', y='Tiempo', color="yellow", label="M2H1-Porcentaje-0.8");
fig = sns.scatterplot(data=M2H1_porcentaje_10, x='N', y='Tiempo', color="purple", label="M2H1-Porcentaje-1.0");

fig.set_title('Tiempos de ejecucion de M2H1 para distintos porcentajes de nodos')
fig.set(xlabel='#Nodos', ylabel='Tiempo en milisegundos');
plt.savefig("graficos/M2H1-porcentajesTime.png");

# %%
fig = sns.scatterplot(data=M2H2_sin_mejoras_500, x='N', y='Tiempo', color="r", label="M2H2-sin-mejoras-500");
fig = sns.scatterplot(data=M2H2_estandarALL, x='N', y='Tiempo', color="g", label="M2H2-sin-mejoras-1000");
fig = sns.scatterplot(data=M2H2_sin_mejoras_2000, x='N', y='Tiempo', color="b", label="M2H2-sin-mejoras-2000");
fig = sns.scatterplot(data=M2H2_sin_mejoras_5000, x='N', y='Tiempo', color="purple", label="M2H2-sin-mejoras-5000");

fig.set_title('Tiempos de ejecucion de M2H2 para distintos CICLOS_MAX_SIN_MEJORAS')
fig.set(xlabel='#Nodos', ylabel='Tiempo en milisegundos');
plt.savefig("graficos/M2H2-sinmejorasTime.png");

# %%
fig = sns.scatterplot(data=M2H1_sin_mejoras_500, x='N', y='Tiempo', color="r", label="M2H1-sin-mejoras-500");
fig = sns.scatterplot(data=M2H1_estandarALL, x='N', y='Tiempo', color="g", label="M2H1-sin-mejoras-1000");
fig = sns.scatterplot(data=M2H1_sin_mejoras_2000, x='N', y='Tiempo', color="b", label="M2H1-sin-mejoras-2000");
fig = sns.scatterplot(data=M2H1_sin_mejoras_5000, x='N', y='Tiempo', color="purple", label="M2H1-sin-mejoras-5000");

fig.set_title('Tiempos de ejecucion de M2H1 para distintos CICLOS_MAX_SIN_MEJORAS')
fig.set(xlabel='#Nodos', ylabel='Tiempo en milisegundos');
plt.savefig("graficos/M2H1-sinmejorasTime.png");

# %%
fig = sns.scatterplot(data=M2H2_max_iter_1000, x='N', y='Tiempo', color="r", label="M2H2-max-iter-1000");
fig = sns.scatterplot(data=M2H2_estandarALL, x='N', y='Tiempo', color="g", label="M2H2-max-iter-5000");
fig = sns.scatterplot(data=M2H2_max_iter_50000, x='N', y='Tiempo', color="b", label="M2H2-max-iter-50000");
fig = sns.scatterplot(data=M2H2_max_iter_100000, x='N', y='Tiempo', color="purple", label="M2H2-max-iter-100000");

fig.set_title('Tiempos de ejecucion de M2H2 para distintos MAX_CANT_ITERACIONES')
fig.set(xlabel='#Nodos', ylabel='Tiempo en milisegundos');
plt.savefig("graficos/M2H2-maxIterTime.png");

# %%
fig = sns.scatterplot(data=M2H1_max_iter_1000, x='N', y='Tiempo', color="r", label="M2H1-max-iter-1000");
fig = sns.scatterplot(data=M2H1_estandarALL, x='N', y='Tiempo', color="g", label="M2H1-max-iter-5000");
fig = sns.scatterplot(data=M2H1_max_iter_50000, x='N', y='Tiempo', color="b", label="M2H1-max-iter-50000");
fig = sns.scatterplot(data=M2H1_max_iter_100000, x='N', y='Tiempo', color="purple", label="M2H1-max-iter-100000");

fig.set_title('Tiempos de ejecucion de M2H1 para distintos MAX_CANT_ITERACIONES')
fig.set(xlabel='#Nodos', ylabel='Tiempo en milisegundos');
plt.savefig("graficos/M2H1-maxIterTime.png");

# %%
fig = sns.scatterplot(data=M2H2_lowestALL, x='N', y='Impacto', color="r", label="M2H2_lowestALL");
fig = sns.scatterplot(data=M2H2_estandarALL, x='N', y='Impacto', color="g", label="M2H2_estandarALL");
fig = sns.scatterplot(data=M2H2_highestALL, x='N', y='Impacto', color="b", label="M2H2_highestALL");

fig.set_title('Impacto de M2H2 (lowest vs estandar vs highest)')
fig.set(xlabel='#Nodos', ylabel='Impacto');
plt.savefig("graficos/M2H2-stdVSlowVShighImpact.png");

# %%
fig = sns.scatterplot(data=M2H1_lowestALL, x='N', y='Impacto', color="r", label="M2H1_lowestALL");
fig = sns.scatterplot(data=M2H1_estandarALL, x='N', y='Impacto', color="g", label="M2H1_estandarALL");
fig = sns.scatterplot(data=M2H1_highestALL, x='N', y='Impacto', color="b", label="M2H1_highestALL");

fig.set_title('Impacto de M2H1 (lowest vs estandar vs highest)')
fig.set(xlabel='#Nodos', ylabel='Impacto');
plt.savefig("graficos/M2H1-stdVSlowVShighImpact.png");

# %%
fig = sns.scatterplot(data=M2H2_porcentaje_02, x='N', y='Impacto', color="r", label="M2H2-Porcentaje-0.2");
fig = sns.scatterplot(data=M2H2_porcentaje_04, x='N', y='Impacto', color="g", label="M2H2-Porcentaje-0.4");
fig = sns.scatterplot(data=M2H2_porcentaje_06, x='N', y='Impacto', color="b", label="M2H2-Porcentaje-0.6");
fig = sns.scatterplot(data=M2H2_estandarALL, x='N', y='Impacto', color="yellow", label="M2H2-Porcentaje-0.8");
fig = sns.scatterplot(data=M2H2_porcentaje_10, x='N', y='Impacto', color="purple", label="M2H2-Porcentaje-1.0");

fig.set_title('Impacto de M2H2 para distintos porcentajes de nodos')
fig.set(xlabel='#Nodos', ylabel='Impacto');
plt.savefig("graficos/M2H2-porcentajesImpact.png");

# %%
fig = sns.scatterplot(data=M2H1_porcentaje_02, x='N', y='Impacto', color="r", label="M2H1-Porcentaje-0.2");
fig = sns.scatterplot(data=M2H1_porcentaje_04, x='N', y='Impacto', color="g", label="M2H1-Porcentaje-0.4");
fig = sns.scatterplot(data=M2H1_porcentaje_06, x='N', y='Impacto', color="b", label="M2H1-Porcentaje-0.6");
fig = sns.scatterplot(data=M2H1_estandarALL, x='N', y='Impacto', color="yellow", label="M2H1-Porcentaje-0.8");
fig = sns.scatterplot(data=M2H1_porcentaje_10, x='N', y='Impacto', color="purple", label="M2H1-Porcentaje-1.0");

fig.set_title('Impacto de M2H1 para distintos porcentajes de nodos')
fig.set(xlabel='#Nodos', ylabel='Impacto');
plt.savefig("graficos/M2H1-porcentajesImpact.png");

# %%
fig = sns.scatterplot(data=M2H2_sin_mejoras_500, x='N', y='Impacto', color="r", label="M2H2-sin-mejoras-500");
fig = sns.scatterplot(data=M2H2_estandarALL, x='N', y='Impacto', color="g", label="M2H2-sin-mejoras-1000");
fig = sns.scatterplot(data=M2H2_sin_mejoras_2000, x='N', y='Impacto', color="b", label="M2H2-sin-mejoras-2000");
fig = sns.scatterplot(data=M2H2_sin_mejoras_5000, x='N', y='Impacto', color="purple", label="M2H2-sin-mejoras-5000");

fig.set_title('Impacto de M2H2 para distintos CICLOS_MAX_SIN_MEJORAS')
fig.set(xlabel='#Nodos', ylabel='Impacto');
plt.savefig("graficos/M2H2-sinmejorasImpact.png");

# %%
fig = sns.scatterplot(data=M2H1_sin_mejoras_500, x='N', y='Impacto', color="r", label="M2H2-sin-mejoras-500");
fig = sns.scatterplot(data=M2H1_estandarALL, x='N', y='Impacto', color="g", label="M2H2-sin-mejoras-1000");
fig = sns.scatterplot(data=M2H1_sin_mejoras_2000, x='N', y='Impacto', color="b", label="M2H2-sin-mejoras-2000");
fig = sns.scatterplot(data=M2H1_sin_mejoras_5000, x='N', y='Impacto', color="purple", label="M2H2-sin-mejoras-5000");

fig.set_title('Impacto de M2H2 para distintos CICLOS_MAX_SIN_MEJORAS')
fig.set(xlabel='#Nodos', ylabel='Impacto');
plt.savefig("graficos/M2H1-sinmejorasImpact.png");

# %%
fig = sns.scatterplot(data=M2H2_max_iter_1000, x='N', y='Impacto', color="r", label="M2H2-max-iter-1000");
fig = sns.scatterplot(data=M2H2_estandarALL, x='N', y='Impacto', color="g", label="M2H2-max-iter-5000");
fig = sns.scatterplot(data=M2H2_max_iter_50000, x='N', y='Impacto', color="b", label="M2H2-max-iter-50000");
fig = sns.scatterplot(data=M2H2_max_iter_100000, x='N', y='Impacto', color="purple", label="M2H2-max-iter-100000");

fig.set_title('Impacto de M2H2 para distintos MAX_CANT_ITERACIONES')
fig.set(xlabel='#Nodos', ylabel='Impacto');
plt.savefig("graficos/M2H2-maxIterImpact.png");

# %%
fig = sns.scatterplot(data=M2H1_max_iter_1000, x='N', y='Impacto', color="r", label="M2H1-max-iter-1000");
fig = sns.scatterplot(data=M2H1_estandarALL, x='N', y='Impacto', color="g", label="M2H1-max-iter-5000");
fig = sns.scatterplot(data=M2H1_max_iter_50000, x='N', y='Impacto', color="b", label="M2H1-max-iter-50000");
fig = sns.scatterplot(data=M2H1_max_iter_100000, x='N', y='Impacto', color="purple", label="M2H1-max-iter-100000");

fig.set_title('Impacto de M2H1 para distintos MAX_CANT_ITERACIONES')
fig.set(xlabel='#Nodos', ylabel='Impacto');
plt.savefig("graficos/M2H1-maxIterImpact.png");
